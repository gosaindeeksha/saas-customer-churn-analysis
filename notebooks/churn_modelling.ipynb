# %% [markdown]
# <h4><b>Importing necessary libraries</b></h4>

# %%
from sklearn.linear_model import LogisticRegression
import pandas as pd
import numpy as np

# %% [markdown]
# <h4><b>Importing behavioural data for trial users</b></h4>

# %%
behavioral_features = pd.read_csv("../data/processed/trial_behavioral_features.csv")
behavioral_features.head()
# Out:
#   account_id signup_date  usage_events_30d  active_days_30d  \
# 0   A-139c3b  2024-11-21              31.0                3
# 1   A-1e50e0  2023-02-21               9.0                1
# 2   A-3b5cd1  2023-09-12              24.0                1
# 3   A-417d2f  2023-07-04              16.0                1
# 4   A-462d45  2024-01-15              11.0                1
#
#    features_used_30d  total_errors_30d  total_usage_time_30d  churn_date  \
# 0                  3               0.0               11593.0         NaN
# 1                  1               4.0                2331.0  2023-11-01
# 2                  2               2.0                5692.0  2024-01-21
# 3                  1               0.0                7680.0  2024-12-30
# 4                  1               0.0                1760.0  2024-05-17
#
#    early_churn  is_active  high_usage
# 0        False       True        True
# 1        False      False       False
# 2        False      False        True
# 3        False      False        True
# 4        False      False       False

# %% [markdown]
# <h4><b>Performing Logistic Regression</b></h4>

# %%
X = behavioral_features[
    ["active_days_30d","total_errors_30d"]
]

y = behavioral_features["early_churn"]

model = LogisticRegression(solver="liblinear")
model.fit(X, y)
# Out:
# LogisticRegression(solver='liblinear')

# %%
coef_df = pd.DataFrame({
    "feature": X.columns,
    "coefficient": model.coef_[0],
    "odds_ratio": np.exp(model.coef_[0])
}).sort_values("odds_ratio")
coef_df
# Out:
#             feature  coefficient  odds_ratio
# 0   active_days_30d    -0.199295    0.819308
# 1  total_errors_30d    -0.048179    0.952963

# %%
behavioral_features["churn_risk"] = model.predict_proba(X)[:, 1]
behavioral_features.sort_values(by="churn_risk", ascending=False)
# Out:
#    account_id signup_date  usage_events_30d  active_days_30d  \
# 10   A-bd4513  2024-11-06              11.0                1
# 11   A-bd4708  2024-07-21               6.0                1
# 19   A-fa2041  2024-05-29               7.0                1
# 18   A-f9cc74  2024-10-12              12.0                1
# 17   A-e08cd3  2024-09-21              11.0                1
# 16   A-de24d5  2024-11-05              12.0                1
# 13   A-cab532  2023-04-03               9.0                1
# 12   A-c16cf7  2024-10-16              12.0                1
# 20   A-fce879  2024-09-24              18.0                1
# 7    A-7f29a7  2024-09-18               8.0                1
# 6    A-4f18f0  2024-04-21              14.0                1
# 4    A-462d45  2024-01-15              11.0                1
# 3    A-417d2f  2023-07-04              16.0                1
# 8    A-87aa7b  2024-05-16               6.0                1
# 14   A-d535f6  2024-09-03               9.0                1
# 2    A-3b5cd1  2023-09-12              24.0                1
# 1    A-1e50e0  2023-02-21               9.0                1
# 9    A-9badbd  2024-06-19              23.0                2
# 15   A-d77f4c  2023-09-25              23.0                2
# 0    A-139c3b  2024-11-21              31.0                3
# 5    A-4bfa33  2024-12-07              52.0                3
#
#     features_used_30d  total_errors_30d  total_usage_time_30d  churn_date  \
# 10                  1               0.0                3080.0  2024-12-07
# 11                  1               0.0                3480.0         NaN
# 19                  1               0.0                4151.0  2024-07-13
# 18                  1               0.0                1188.0         NaN
# 17                  1               0.0                1694.0  2024-09-21
# 16                  1               0.0                5412.0         NaN
# 13                  1               0.0                2835.0  2024-07-10
# 12                  1               0.0                3744.0  2024-11-08
# 20                  1               0.0                4698.0  2024-10-07
# 7                   1               0.0                1800.0  2024-10-09
# 6                   1               0.0                5334.0  2024-05-27
# 4                   1               0.0                1760.0  2024-05-17
# 3                   1               0.0                7680.0  2024-12-30
# 8                   1               1.0                3090.0  2024-06-07
# 14                  1               2.0                1683.0  2024-10-05
# 2                   2               2.0                5692.0  2024-01-21
# 1                   1               4.0                2331.0  2023-11-01
# 9                   2               1.0                2103.0         NaN
# 15                  2               1.0                8128.0  2024-08-06
# 0                   3               0.0               11593.0         NaN
# 5                   4               3.0               12135.0  2024-12-08
#
#     early_churn  is_active  high_usage  churn_risk
# 10         True      False       False    0.490452
# 11        False      False        True    0.490452
# 19         True      False        True    0.490452
# 18        False      False       False    0.490452
# 17         True      False       False    0.490452
# 16        False      False        True    0.490452
# 13        False      False       False    0.490452
# 12         True      False        True    0.490452
# 20         True      False        True    0.490452
# 7          True      False       False    0.490452
# 6          True      False        True    0.490452
# 4         False      False       False    0.490452
# 3         False      False        True    0.490452
# 8          True      False       False    0.478419
# 14         True      False       False    0.466412
# 2         False      False        True    0.466412
# 1         False      False       False    0.442526
# 9         False       True       False    0.429064
# 15        False       True        True    0.429064
# 0         False       True        True    0.392507
# 5          True       True        True    0.358627
